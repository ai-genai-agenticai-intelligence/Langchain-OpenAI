# %%
# pip install -U "langchain[openai]" 
# !pip install -U  "langchain[google-genai]"
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from langchain.chat_models import init_chat_model

# Gemini API Key
os.environ["GOOGLE_API_KEY"] = "AIzaSyDV_WqVZMohZRVEgb-1nL2e9KgVhO5HL3o"

# Initialize model correctly
model = init_chat_model(
    model="gemini-2.5-flash",
    model_provider="google_genai"
)

# %%
response =model.invoke('job opportunity in 2027')

# %%
response = model.invoke("about india economy")

# %%
print(response)
# Out:
# content='India\'s economy is one of the most dynamic and rapidly growing in the world, characterized by its large size, diverse sectors, and significant potential, but also facing considerable challenges.\n\nHere\'s a comprehensive overview:\n\n### **1. Key Characteristics & Overview**\n\n*   **Size:** India is currently the **5th largest economy in the world by nominal GDP** and the **3rd largest by Purchasing Power Parity (PPP)**. It\'s on track to become the 3rd largest by nominal GDP in the coming years.\n*   **Growth Engine:** India is consistently one of the **fastest-growing major economies globally**, often projected to maintain a strong growth trajectory even amidst global headwinds.\n*   **Demographic Dividend:** With a large, young, and growing population, India possesses a significant workforce potential, often referred to as a "demographic dividend."\n*   **Mixed Economy:** It\'s a mixed economy with significant public and private sector participation, and a growing emph
# ...

# %%
print(response.text)
# Out:
# Predicting specific job opportunities for 2027 involves looking at current trends and projecting their evolution. The job market will continue to be shaped by rapid technological advancements, environmental concerns, demographic shifts, and evolving work models.
#
# Here's a breakdown of key trends, in-demand sectors, essential skills, and advice for preparing for the job market in 2027:
#
# ---
#
# ## Overarching Trends Shaping the 2027 Job Market
#
# 1.  **AI and Automation Integration:** AI won't just replace jobs; it will augment many and create entirely new ones. Proficiency in working *with* AI will be crucial.
# 2.  **Sustainability and Green Economy:** Climate change concerns will drive significant investment and job creation in renewable energy, circular economy, and sustainable practices across all industries.
# 3.  **Continued Digital Transformation:** Cloud computing, big data, IoT, cybersecurity, and advanced connectivity will be foundational.
# ...

# %% [markdown]
# # Language Transalation

# %%
from langchain_core.messages import HumanMessage, SystemMessage
messages =[
    SystemMessage('Translate the following from English into odia language'),
    HumanMessage('how are you teams working on language with google gemini model?'),

]
model.invoke(messages)
# Out:
# AIMessage(content='ଆପଣଙ୍କ ଟିମ୍\u200cମାନେ ଗୁଗୁଲ୍ ଜେମିନି ମଡେଲ୍ ସହିତ ଭାଷା ଉପରେ କିପରି କାମ କରୁଛନ୍ତି?\n\n(Aapaṇanka team-mane Google Gemini Model sahita bhāṣā upare kipari kāma karuchanti?)', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e3e43-8ad0-79e0-80bb-6559d890fbca-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 23, 'output_tokens': 1180, 'total_tokens': 1203, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1100}})

# %%
response1 =model.invoke(messages)

# %%
print(response1)
# Out:
# content='ଆପଣଙ୍କ ଟିମ୍\u200cମାନେ ଗୁଗୁଲ୍ ଜେମିନି ମଡେଲ୍ ସହିତ ଭାଷା ଉପରେ କିପରି କାମ କରୁଛନ୍ତି?' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019e3e44-2f74-7633-838b-c571499061b9-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 23, 'output_tokens': 1502, 'total_tokens': 1525, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1450}}

# %%
print(response1.text)
# Out:
# ଆପଣଙ୍କ ଟିମ୍‌ମାନେ ଗୁଗୁଲ୍ ଜେମିନି ମଡେଲ୍ ସହିତ ଭାଷା ଉପରେ କିପରି କାମ କରୁଛନ୍ତି?

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage("Translate the following from hindi to english language"),
    HumanMessage("बहत अच्छा टीम वर्क कर रहे हो आप लोग"),
]

model.invoke(messages)
# Out:
# AIMessage(content='Here are a few ways to translate "बहत अच्छा टीम वर्क कर रहे हो आप लोग" into English, depending on the nuance you want:\n\n*   **You all are doing excellent teamwork.** (Direct and common)\n*   **You\'re doing great teamwork.** (More concise)\n*   **You all are doing very good teamwork.**\n*   **Excellent teamwork, everyone!** (More of an exclamation of praise)\n*   **You guys are doing fantastic teamwork.** (More informal)', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e3e45-bbd9-7962-9f4c-fbd2cba72cc6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 826, 'total_tokens': 845, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 721}})

# %%
response2 =model.invoke(messages)

# %%
print(response2)
# Out:
# content='Here are a few ways to translate "बहुत अच्छा टीम वर्क कर रहे हो आप लोग" into English, depending on the desired tone:\n\n1.  **You all are doing very good teamwork.** (Most direct translation)\n2.  **You all are doing excellent teamwork.**\n3.  **You guys are doing great teamwork.** (More casual)\n4.  **You\'re doing great teamwork.** (Implies "you all" in context)\n5.  **You\'re doing a fantastic job with the teamwork.** (Slightly more elaborate)' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019e3e46-41f3-7f60-80e7-ed956d9f2ec1-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 19, 'output_tokens': 476, 'total_tokens': 495, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 358}}

# %%
print(response2.text)
# Out:
# Here are a few ways to translate "बहुत अच्छा टीम वर्क कर रहे हो आप लोग" into English, depending on the desired tone:
#
# 1.  **You all are doing very good teamwork.** (Most direct translation)
# 2.  **You all are doing excellent teamwork.**
# 3.  **You guys are doing great teamwork.** (More casual)
# 4.  **You're doing great teamwork.** (Implies "you all" in context)
# 5.  **You're doing a fantastic job with the teamwork.** (Slightly more elaborate)

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage("Translate the following from Hindi to Telugu language"),
    HumanMessage("बहत अच्छा टीम वर्क कर रहे हो आप लोग"),
]

model.invoke(messages)
# Out:
# AIMessage(content='మీరు చాలా మంచి టీమ్\u200cవర్క్ చేస్తున్నారు.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e3e47-a6cd-7ce3-90b3-0a08b5aa4add-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 1031, 'total_tokens': 1050, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1021}})

# %%
response3 =model.invoke(messages)

# %%
print(response3)
# Out:
# content='మీరు చాలా బాగా టీమ్ వర్క్ చేస్తున్నారు.\n\n(Meeru chāla bāgā team work chestunnāru.)\n\nA slightly stronger alternative:\nమీరు అద్భుతమైన టీమ్ వర్క్ చేస్తున్నారు.\n(Meeru adbhutamaina team work chestunnāru.)' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019e3e48-0aa9-7a72-beb5-7c833cba221d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 19, 'output_tokens': 1666, 'total_tokens': 1685, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1604}}

# %%
print(response3.text)
# Out:
# మీరు చాలా బాగా టీమ్ వర్క్ చేస్తున్నారు.
#
# (Meeru chāla bāgā team work chestunnāru.)
#
# A slightly stronger alternative:
# మీరు అద్భుతమైన టీమ్ వర్క్ చేస్తున్నారు.
# (Meeru adbhutamaina team work chestunnāru.)

# %% [markdown]
# # Prompt Template

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = "Translate the following from English into {language}"

prompt_template = ChatPromptTemplate.from_messages(
    [("system", system_template),("user", "{text}")]
)

# %%
prompt = prompt_template.invoke({"language":"odia","text":"how are you"})
prompt
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the following from English into odia', additional_kwargs={}, response_metadata={}), HumanMessage(content='how are you', additional_kwargs={}, response_metadata={})])

# %%
prompt.to_messages()
# Out:
# [SystemMessage(content='Translate the following from English into odia', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='how are you', additional_kwargs={}, response_metadata={})]

# %%
response4 = model.invoke(prompt)
print(response4.content)
# Out:
# **କେମିତି ଅଛନ୍ତି?** (Kemiti achhanti?)
#
# This is the most common and polite way to say "How are you?" in Odia.
#
# You could also say:
# *   **କେମିତି ଅଛ?** (Kemiti achha?) - Less formal, for a peer or someone you know well.
# *   **କେମିତି ଅଛୁ?** (Kemiti achhu?) - Informal, for a close friend or someone younger.

# %% [markdown]
# # Hugging Face Embadding

# %%
pip install -qu langchain  langchain-huggingface sentence_transformers
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [optparse.groups]Usage:[/]
#   c:\Users\abhis\AppData\Local\Programs\Python\Python314\python.exe -m pip install \[options] <requirement specifier> \[package-index-options] ...
#   c:\Users\abhis\AppData\Local\Programs\Python\Python314\python.exe -m pip install \[options] -r <requirements file> \[package-index-options] ...
#   c:\Users\abhis\AppData\Local\Programs\Python\Python314\python.exe -m pip install \[options] [-e] <vcs project url> ...
#   c:\Users\abhis\AppData\Local\Programs\Python\Python314\python.exe -m pip install \[options] [-e] <local project path> ...
#   c:\Users\abhis\AppData\Local\Programs\Python\Python314\python.exe -m pip install \[options] <archive url/path> ...
#
# no such option: -u

# %%
from langchain_huggingface.embeddings import HuggingFaceEmbeddings

# %%
from langchain_huggingface.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-mpnet-base-v2"
)
# Out:
# ...
# c:\Users\abhis\AppData\Local\Programs\Python\Python314\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\abhis\.cache\huggingface\hub\models--sentence-transformers--all-mpnet-base-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
text ="This is a text document."

# %%
query_result = embeddings.embed_query(text)

# %%
print(query_result)
# Out:
# [-0.020825127139687538, -0.08258461207151413, 0.008213656023144722, 0.06416936963796616, -0.022167053073644638, 0.015889612957835197, -0.011644957587122917, 0.04668400436639786, -0.010806395672261715, -0.04112686589360237, 0.048478566110134125, 0.0057635316625237465, 0.015643367543816566, -0.010882971808314323, -0.030312534421682358, -0.024692807346582413, 0.052972372621297836, 0.021250825375318527, 0.028585469350218773, 0.029743654653429985, -0.01821156032383442, 0.03631584718823433, -0.0004925462999381125, -0.01380289625376463, -0.018943767994642258, -0.012591029517352581, -0.034433480352163315, -0.0130144152790308, -0.015480062924325466, -0.03475358337163925, -0.045791976153850555, 0.024947186931967735, 0.01879098080098629, -0.051786910742521286, 1.5980517673597205e-06, -0.027442755177617073, -0.059998124837875366, -0.007413955871015787, 0.017817297950387, 0.018640683963894844, 0.06339613348245621, 0.04452932998538017, -0.07998516410589218, 0.021781031042337418, 0.0116070872172713
# ...
